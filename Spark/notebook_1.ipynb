# %%
from pyspark.sql import SparkSession
import json

# %%
with open("../config/spark_config.json", "r") as f:
    config = json.load(f)

# %%
spark = SparkSession.builder \
    .appName(config["spark"]["appName"]) \
    .config("spark.hadoop.fs.defaultFS", config["spark"]["hadoop"]["fs.defaultFS"]) \
    .config("spark.hadoop.hadoop.home.dir", config["spark"]["hadoop"]["home.dir"]) \
    .config("spark.executor.memory", config["spark"]["memory"]["executor"]) \
    .config("spark.driver.memory", config["spark"]["memory"]["driver"]) \
    .getOrCreate()
# Out:
# 25/01/16 20:14:43 WARN Utils: Your hostname, Ala resolves to a loopback address: 127.0.1.1; using 10.255.255.254 instead (on interface lo)
# 25/01/16 20:14:43 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 25/01/16 20:14:43 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://10.255.255.254:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.5.3</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>HadoopToSparkApp</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
hdfs_path="hdfs://172.18.0.2:9000/user/ala/uniprot_data_with_ec.csv"
protein_df = spark.read.option("header", "true").csv(hdfs_path)
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# Cell In[5], line 2
#       1 hdfs_path="hdfs://172.18.0.2:9000/user/ala/uniprot_data_with_ec.csv"
# ----> 2 protein_df = spark.read.option("header", "true").csv(hdfs_path)
#
# File ~/.local/lib/python3.10/site-packages/pyspark/sql/readwriter.py:740, in DataFrameReader.csv(self, path, schema, sep, encoding, quote, escape, comment, header, inferSchema, ignoreLeadingWhiteSpace, ignoreTrailingWhiteSpace, nullValue, nanValue, positiveInf, negativeInf, dateFormat, timestampFormat, maxColumns, maxCharsPerColumn, maxMalformedLogPerPartition, mode, columnNameOfCorruptRecord, multiLine, charToEscapeQuoteEscaping, samplingRatio, enforceSchema, emptyValue, locale, lineSep, pathGlobFilter, recursiveFileLookup, modifiedBefore, modifiedAfter, unescapedQuoteHandling)
#     738 if type(path) == list:
#     739     assert self._spark._sc._jvm is not None
# --> 740     return self._df(self._jreader.csv(self._spark._sc._jvm.PythonUtils.toSeq(path)))
#     741 elif isinstance(path, RDD):
#     743     def func(iterator):
#
# File ~/.local/lib/python3.10/site-packages/py4j/java_gateway.py:1322, in JavaMember.__call__(self, *args)
#    1316 command = proto.CALL_COMMAND_NAME +\
#    1317     self.command_header +\
#    1318     args_command +\
#    1319     proto.END_COMMAND_PART
#    1321 answer = self.gateway_client.send_command(command)
# -> 1322 return_value = get_return_value(
#    1323     answer, self.gateway_client, self.target_id, self.name)
#    1325 for temp_arg in temp_args:
#    1326     if hasattr(temp_arg, "_detach"):
#
# File ~/.local/lib/python3.10/site-packages/pyspark/errors/exceptions/captured.py:185, in capture_sql_exception.<locals>.deco(*a, **kw)
#     181 converted = convert_exception(e.java_exception)
#     182 if not isinstance(converted, UnknownException):
#     183     # Hide where the exception came from that shows a non-Pythonic
#     184     # JVM exception message.
# --> 185     raise converted from None
#     186 else:
#     187     raise
#
# AnalysisException: [PATH_NOT_FOUND] Path does not exist: hdfs://172.18.0.2:9000/user/ala/uniprot_data_with_ec.csv.

# %%
path="hdfs://172.18.0.2:9000/user/ala/fichier_part1.tsv"
protein_df  = spark.read.option("header","true")\
                    .option("sep", "\t")\
                    .option("multiLine", "true")\
                    .option("quote","\"")\
                    .option("escape","\"")\
                    .option("ignoreTrailingWhiteSpace", True)\
                    .csv(path)

# %%
protein_df = protein_df.repartition(100)

# %%
protein_df.cache()
# Out:
# DataFrame[Entry: string, Entry Name: string, Protein Names: string, Gene Names: string, Organism: string, Length: string, Sequence: string, EC Number: string, InterPro Cross-reference: string]

# %%
protein_df.show()
# Out:
# +----------+-----------+--------------------+----------+------------+------+--------------------+----------+------------------------+
# |     Entry| Entry Name|       Protein Names|Gene Names|    Organism|Length|            Sequence| EC Number|InterPro Cross-reference|
# +----------+-----------+--------------------+----------+------------+------+--------------------+----------+------------------------+
# |A0A0C5B5G6|MOTSC_HUMAN|Mitochondrial-der...|   MT-RNR1|Homo sapiens|    16|    MRWQEMGYIFYPRKLR|      NULL|               IPR054130|
# |A0A1B0GTW7|CIROP_HUMAN|Ciliated left-rig...|     CIROP|Homo sapiens|   788|MLLLLLLLLLLPPLVLR...|  3.4.24.-|               IPR001577|
# |    A0JNW5|BLT3B_HUMAN|Bridge-like lipid...|    BLTP3B|Homo sapiens|  1464|MAGIIKKQILKHLSRFT...|      NULL|    IPR026728; IPR026854|
# |    A0JP26|POTB3_HUMAN|POTE ankyrin doma...|    POTEB3|Homo sapiens|   581|MVAEVCSMPAASAVKKP...|      NULL|    IPR050657; IPR002...|
# |    A0PK11|CLRN2_HUMAN|            Clarin-2|     CLRN2|Homo sapiens|   232|MPGWFKKAWYGLASLLS...|      NULL|               IPR026748|
# |    A1A4S6|RHG10_HUMAN|Rho GTPase-activa...|  ARHGAP10|Homo sapiens|   786|MGLQPLEFSDCYLDSPW...|      NULL|    IPR027267; IPR004...|
# |    A1A519|F170A_HUMAN|     Protein FAM170A|   FAM170A|Homo sapiens|   330|MKRRQKRKHLENEESQE...|      NULL|               IPR040879|
# |    A1L190|SYCE3_HUMAN|Synaptonemal comp...|     SYCE3|Homo sapiens|    88|MDDADPEERNYDNMLKM...|      NULL|               IPR028145|
# |    A1L3X0|ELOV7_HUMAN|Very long chain f...|    ELOVL7|Homo sapiens|   281|MAFSDLTSRTVHLYDNW...| 2.3.1.199|    IPR030457; IPR002...|
# |    A1X283|SPD2B_HUMAN|SH3 and PX domain...|  SH3PXD2B|Homo sapiens|   911|MPPRRSIVEVKVLDVQK...|      NULL|    IPR051228; IPR001...|
# |    A2A2Y4|FRMD3_HUMAN|FERM domain-conta...|     FRMD3|Homo sapiens|   597|MFASCHCVPRGRRTMKM...|      NULL|    IPR019749; IPR000...|
# |    A2RU14|TM218_HUMAN|Transmembrane pro...|   TMEM218|Homo sapiens|   115|MAGTVLGVGAGVFILAL...|      NULL|               IPR026771|
# |    A2RUB6|CCD66_HUMAN|Coiled-coil domai...|    CCDC66|Homo sapiens|   948|MNLGDGLKLETELLDGK...|      NULL|    IPR039183; IPR040467|
# |    A2RUC4| TYW5_HUMAN|tRNA wybutosine-s...|      TYW5|Homo sapiens|   315|MAGQHLPVPRLEGVSRE...|1.14.11.42|    IPR041667; IPR003347|
# |    A4D1B5| GSAP_HUMAN|Gamma-secretase-a...|      GSAP|Homo sapiens|   854|MALRLVADFDLGKDVLP...|      NULL|    IPR028010; IPR026172|
# |    A4GXA9| EME2_HUMAN|Probable crossove...|      EME2|Homo sapiens|   379|MARVGPGRAGVSCQGRG...|  3.1.22.-|    IPR042530; IPR006...|
# |    A5D8V7|ODAD3_HUMAN|Outer dynein arm-...|     ODAD3|Homo sapiens|   595|MTSPLCRAASANALPPQ...|      NULL|               IPR033192|
# |    A5PLL7|PDES1_HUMAN|Plasmanylethanola...|     PEDS1|Homo sapiens|   270|MAGAENWPGQQLELDED...|1.14.19.77|    IPR019547; IPR052601|
# |    A6BM72|MEG11_HUMAN|Multiple epiderma...|    MEGF11|Homo sapiens|  1044|MVLSLTGLIAFSFLQAT...|      NULL|    IPR013032; IPR000...|
# |    A6H8Y1| BDP1_HUMAN|Transcription fac...|      BDP1|Homo sapiens|  2624|MFRRARLSVKPNVRPGV...|      NULL|    IPR009057; IPR001...|
# +----------+-----------+--------------------+----------+------------+------+--------------------+----------+------------------------+
# only showing top 20 rows

# %%
protein_df.unpersist()
# Out:
# DataFrame[Entry: string, Entry Name: string, Protein Names: string, Gene Names: string, Organism: string, Length: string, Sequence: string, EC Number: string, InterPro Cross-reference: string]

# %%
#path="hdfs://172.18.0.2:9000/user/ala/uniprot_data_first_3000.tsv"
#protein_df  = spark.read.option("header","true")\
#                    .option("sep", "\t")\
#                    .option("multiLine", "true")\
#                    .option("quote","\"")\
#                    .option("escape","\"")\
#                    .option("ignoreTrailingWhiteSpace", True)\
#                    .csv(path)

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, udf
from pyspark.sql.types import ArrayType, StringType
from collections import defaultdict

# %%
protein_df.show(50)
# Out:
# +----------+----------+----------------+--------------------+--------------------+--------------------+------+--------------------+--------------------+--------------------+
# |     Entry|  Reviewed|      Entry Name|       Protein names|          Gene Names|            Organism|Length|            Sequence|           EC number|            InterPro|
# +----------+----------+----------------+--------------------+--------------------+--------------------+------+--------------------+--------------------+--------------------+
# |A0A075F5C6|unreviewed|A0A075F5C6_MOUSE|Heat shock factor...|                Hsf1|Mus musculus (Mouse)|   531|MDLAVGPGAAGPSNVPA...|                NULL|IPR000232;IPR0277...|
# |A0A087WPF7|  reviewed|     AUTS2_MOUSE|Autism susceptibi...|      Auts2 Kiaa0442|Mus musculus (Mouse)|  1261|MDGPTRGHGLRKKRRSR...|                NULL|          IPR023246;|
# |A0A087WRK1|unreviewed|A0A087WRK1_MOUSE|Predicted gene, 2...|Gm20905 Gm20814 G...|Mus musculus (Mouse)|   222|MRRMALKKLKVIPKEGY...|                NULL|IPR051443;IPR006888;|
# |A0A087WRT4|unreviewed|A0A087WRT4_MOUSE|FAT atypical cadh...|                Fat1|Mus musculus (Mouse)|  4602|MGRHLTLLLLLLLFLQQ...|                NULL|IPR039808;IPR0021...|
# |A0A087WSP5|unreviewed|A0A087WSP5_MOUSE|Signal transducer...|               Stat1|Mus musculus (Mouse)|   755|MSQWFELQQLDSKFLEQ...|                NULL|IPR008967;IPR0009...|
# |A0A088MLT8|  reviewed|     IQIP1_MOUSE|IQCJ-SCHIP1 readt...|Iqcj-Schip1 Iqsch...|Mus musculus (Mouse)|   559|MRLEELKRLQNPLEQVD...|                NULL|IPR029362;IPR0390...|
# |A0A0A6YXR0|unreviewed|A0A0A6YXR0_MOUSE|Choline/ethanolam...|               Cept1|Mus musculus (Mouse)|   247|MSGHRSTRKRCGDSHPE...|2.7.8.1; 2.7.8.2;...|IPR000462;IPR0431...|
# |A0A0A6YXU9|unreviewed|A0A0A6YXU9_MOUSE|Transforming grow...|               Tgfb2|Mus musculus (Mouse)|   442|MHYCVLSTFLLLHLVPV...|                NULL|IPR029034;IPR0018...|
# |A0A0B4J1F4|  reviewed|     ARRD4_MOUSE|Arrestin domain-c...|              Arrdc4|Mus musculus (Mouse)|   415|MGGEAGADGPRGRVKSL...|                NULL|IPR014752;IPR0110...|
# |A0A0B4J1G0|  reviewed|     FCG3A_MOUSE|Low affinity immu...|        Fcgr4 Fcgr3a|Mus musculus (Mouse)|   249|MWQLLLPTALVLTAFSG...|                NULL|IPR007110;IPR0361...|
# |A0A0B4J1N3|  reviewed|     GP15L_MOUSE|Protein GPR15LG (...|      Gpr15lg Gpr15l|Mus musculus (Mouse)|    78|MRLLALSGLLCMLLLCF...|                NULL|          IPR031713;|
# |A0A0G2JDV3|  reviewed|      GBP6_MOUSE|Guanylate-binding...|          Gbp6 Mpa2l|Mus musculus (Mouse)|   611|MTQPQMAPICLVENHNE...|             3.6.5.-|IPR030386;IPR0376...|
# |A0A0G2JGI9|unreviewed|A0A0G2JGI9_MOUSE|Glycogen debranch...|                 Agl|Mus musculus (Mouse)|  1279|MEHSKQIRILLLNEMEK...|  2.4.1.25; 3.2.1.33|IPR008928;IPR0104...|
# |A0A1L1SUV7|unreviewed|A0A1L1SUV7_MOUSE|Solute carrier fa...|             Slc37a4|Mus musculus (Mouse)|   102|MAAQGYGYYRTVIFAAM...|                NULL|IPR011701;IPR0208...|
# |A0A1L1SV42|unreviewed|A0A1L1SV42_MOUSE|Solute carrier fa...|             Slc37a4|Mus musculus (Mouse)|    96|MAAQGYGYYRTVIFAAM...|                NULL|IPR036259;IPR051337;|
# |A0A1W2P872|  reviewed|     NOVA2_MOUSE|RNA-binding prote...|               Nova2|Mus musculus (Mouse)|   492|MEPEAPDSRKRPLETPP...|                NULL|IPR047275;IPR0472...|
# |A0A1Y7VMN0|unreviewed|A0A1Y7VMN0_MOUSE|Rho-associated pr...|               Rock2|Mus musculus (Mouse)|  1444|MSRPPPTGKMPGAPETA...|            2.7.11.1|IPR000961;IPR0463...|
# |A0A1Y7VMP7|unreviewed|A0A1Y7VMP7_MOUSE|      MutL homolog 3|                Mlh3|Mus musculus (Mouse)|  1443|MIRCLSDDVKTKLRSGL...|                NULL|IPR014762;IPR0135...|
# |A0A286YE25|unreviewed|A0A286YE25_MOUSE|Spastin (EC 5.6.1.1)|    Spast SPAST SPG4|Mus musculus (Mouse)|   613|MSSPAGRRKKKGSGGAS...|             5.6.1.1|IPR003593;IPR0415...|
# |A0A2R3XZC4|unreviewed|A0A2R3XZC4_MOUSE|Stimulator of int...|Sting1 STING Tmem173|Mus musculus (Mouse)|   378|MPYSNLHPAIPRPRGHR...|                NULL|IPR029158;IPR0471...|
# |A0A2R8VHR8|  reviewed|     DT3UO_MOUSE|DDIT3 upstream op...|               Ddit3|Mus musculus (Mouse)|    34|MLKMSGWQRQSQNNSRN...|                NULL|                NULL|
# +----------+----------+----------------+--------------------+--------------------+--------------------+------+--------------------+--------------------+--------------------+
# only showing top 50 rows

# %%
protein_df_all = protein_df.filter(col("InterPro").isNotNull())

# %%
from pyspark.sql.functions import udf

# %%
split_domains_udf = udf(lambda x: x.split(";") if x else [], ArrayType(StringType()))

# %%
protein_df = protein_df_all.withColumn("domain_list", split_domains_udf(col("InterPro")))

# %%
protein_df.show()
# Out:
# +----------+----------+----------------+--------------------+--------------------+--------------------+------+--------------------+--------------------+--------------------+--------------------+
# |     Entry|  Reviewed|      Entry Name|       Protein names|          Gene Names|            Organism|Length|            Sequence|           EC number|            InterPro|         domain_list|
# +----------+----------+----------------+--------------------+--------------------+--------------------+------+--------------------+--------------------+--------------------+--------------------+
# |A0A075F5C6|unreviewed|A0A075F5C6_MOUSE|Heat shock factor...|                Hsf1|Mus musculus (Mouse)|   531|MDLAVGPGAAGPSNVPA...|                NULL|IPR000232;IPR0277...|[IPR000232, IPR02...|
# |A0A087WPF7|  reviewed|     AUTS2_MOUSE|Autism susceptibi...|      Auts2 Kiaa0442|Mus musculus (Mouse)|  1261|MDGPTRGHGLRKKRRSR...|                NULL|          IPR023246;|       [IPR023246, ]|
# |A0A087WRK1|unreviewed|A0A087WRK1_MOUSE|Predicted gene, 2...|Gm20905 Gm20814 G...|Mus musculus (Mouse)|   222|MRRMALKKLKVIPKEGY...|                NULL|IPR051443;IPR006888;|[IPR051443, IPR00...|
# |A0A0R4IZY3|unreviewed|A0A0R4IZY3_MOUSE|Fibroblast growth...|               Fgfr4|Mus musculus (Mouse)|   799|MWLLLALLSIFQGTPAL...|            2.7.10.1|IPR016248;IPR0071...|[IPR016248, IPR00...|
# |A0A0R4J008|unreviewed|A0A0R4J008_MOUSE|Histone deacetyla...|               Hdac2|Mus musculus (Mouse)|   488|MAYSQGGGKKKVCYYYD...|            3.5.1.98|IPR050284;IPR0002...|[IPR050284, IPR00...|
# |A0A0R4J049|unreviewed|A0A0R4J049_MOUSE|Protein arginine ...|               Prmt5|Mus musculus (Mouse)|   637|MAAMAVGGAGGSRVSSG...|           2.1.1.320|IPR025799;IPR0078...|[IPR025799, IPR00...|
# |A0A0R4J083|unreviewed|A0A0R4J083_MOUSE|Long-chain specif...|               Acadl|Mus musculus (Mouse)|   430|MAARLLLRSLRVLSARS...|             1.3.8.8|IPR006089;IPR0060...|[IPR006089, IPR00...|
# +----------+----------+----------------+--------------------+--------------------+--------------------+------+--------------------+--------------------+--------------------+--------------------+
# only showing top 20 rows

# %%
# Fonction pour calculer la similarité de Jaccard
def jaccard_similarity(domains1, domains2):
    if domains1 is None or domains2 is None:
        return 0.0
    set1 = set(domains1)
    set2 = set(domains2)
    intersection = len(set1 & set2)
    union = len(set1 | set2)
    if union == 0:
        return 0.0
    return intersection / union

# %%
import itertools
# Fonction pour calculer la similarité de Jaccard sur des paires uniques
def calculate_jaccard_on_pairs(df, threshold):
    results = []
    
    # Collecter les données dans une liste
    protein_data = df.select("Entry", "domain_list").collect()
    
    # Générer des paires uniques avec itertools.combinations
    for (row1, row2) in itertools.combinations(protein_data, 2):
        domains1 = row1["domain_list"]
        domains2 = row2["domain_list"]
        
        similarity = jaccard_similarity(domains1, domains2)
        
        if similarity >= threshold:
            results.append((row1["Entry"], row2["Entry"], similarity))
    
    return results

# %%
# Calculer les similarités avec un seuil de 0.4
similarity_data = calculate_jaccard_on_pairs(protein_df, threshold=0.7)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[19], line 2
#       1 # Calculer les similarités avec un seuil de 0.4
# ----> 2 similarity_data = calculate_jaccard_on_pairs(protein_df, threshold=0.7)
#
# Cell In[17], line 14, in calculate_jaccard_on_pairs(df, threshold)
#      11 domains1 = row1["domain_list"]
#      12 domains2 = row2["domain_list"]
# ---> 14 similarity = jaccard_similarity(domains1, domains2)
#      16 if similarity >= threshold:
#      17     results.append((row1["Entry"], row2["Entry"], similarity))
#
# Cell In[14], line 8, in jaccard_similarity(domains1, domains2)
#       6 set2 = set(domains2)
#       7 intersection = len(set1 & set2)
# ----> 8 union = len(set1 | set2)
#       9 if union == 0:
#      10     return 0.0
#
# KeyboardInterrupt:

# %%
len(similarity_data)
# Out:
# 158

# %%
test = similarity_data[:30]

# %%
import matplotlib.pyplot as plt
import networkx as nx

# %%
G = nx.Graph()

for edge in test:
    protein1, protein2, similarity = edge
    G.add_edge(protein1, protein2, weight=similarity)

pos = nx.spring_layout(G, k=0.5, iterations=50)

plt.figure(figsize=(10, 8))

nx.draw_networkx_nodes(G, pos, node_size=2000, node_color='lightblue', alpha=0.8)
nx.draw_networkx_edges(G, pos, width=2, edge_color='gray', alpha=0.7)
nx.draw_networkx_labels(G, pos, font_size=12, font_weight='bold', font_family='sans-serif')

edge_labels = {(u, v): f"{d['weight']:.2f}" for u, v, d in G.edges(data=True)}
nx.draw_networkx_edge_labels(G, pos, edge_labels=edge_labels, font_color='red', font_size=10)

plt.title("Graphe de similarité entre les protéines", fontsize=14)
plt.axis('off')
plt.tight_layout()
plt.show()

# %%
spark.stop()
